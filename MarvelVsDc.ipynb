# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-84f75cbf-fa5b-4524-898a-1bb24c462228" name="files[]" multiple disabled />
#      <output id="result-84f75cbf-fa5b-4524-898a-1bb24c462228">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving db.csv to db.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('db.csv', encoding='latin1')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Original Title', 'Company', 'Rate', 'Metascore',
#        'Minutes', 'Release', 'Budget', 'Opening Weekend USA', 'Gross USA',
#        'Gross Worldwide'],
#       dtype='object')

# %%
print(df.head(3))
sns.set_style('dark')
# Out:
#    Unnamed: 0       Original Title  ...  Gross USA  Gross Worldwide
# 0           1             Iron Man  ...  318604126        585366247
# 1           2  The Incredible Hulk  ...  134806913        263427551
# 2           3           Iron Man 2  ...  312433331        623933331
#
# [3 rows x 11 columns]

# %%
df.head(3)
# Out:
#    Unnamed: 0       Original Title  ... Gross Worldwide     Profit
# 0           1             Iron Man  ...       585366247  445366247
# 1           2  The Incredible Hulk  ...       263427551  113427551
# 2           3           Iron Man 2  ...       623933331  423933331
#
# [3 rows x 12 columns]

# %%
sns.countplot(x = df['Company'])
plt.title('Number of Movies')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df_2 = df.sort_values('Gross Worldwide', ascending=False)
sns.barplot(x = df_2['Original Title'], y = df_2['Gross Worldwide'], data=df_2, order = df_2['Original Title'][:10] )
plt.xticks(rotation = 90)
plt.title('Top 10 Highest Grossing')
plt.xlabel('Movie Title')
plt.ylabel('Worldwide Gross')
# Out:
# Text(0, 0.5, 'Worldwide Gross')

# %%
my_pal = {"Marvel": "Red", "DC": "#add8e6"}
sns.boxplot(x = df_2['Company'], y = df_2['Gross Worldwide'], data=df_2, hue = 'Company', palette = my_pal)
plt.xticks(rotation = 90)
plt.title('Gross for all Movies')
plt.xlabel('Company')
plt.ylabel('Worldwide Gross')
# Out:
# Text(0, 0.5, 'Worldwide Gross')

# %%
df_3 = df.sort_values('Rate', ascending=False)
sns.barplot(x = df_3['Original Title'], y = df_3['Rate'], data=df_3, order = df_3['Original Title'][:10], palette = 'Blues_d')
plt.xticks(rotation = 90)
plt.xlabel('Movie Title')
plt.ylabel('Rating')
plt.title('Ranked by IMDB')
# Out:
# Text(0.5, 1.0, 'Ranked by IMDB')

# %%
df_4 = df.sort_values('Metascore', ascending=False)
sns.barplot(x = df_4['Original Title'], y = df_4['Metascore'], data=df_4, order = df_4['Original Title'][:10] , palette = 'Greens_d')
plt.xticks(rotation = 90)
plt.xlabel('Movie Title')
plt.ylabel('Score')
plt.title('Metacritic Score')
# Out:
# Text(0.5, 1.0, 'Metacritic Score')

# %%
df = df.astype({'Budget': 'int64'})
df['Profit'] = df['Gross Worldwide'] - df['Budget']
df.columns
# Out:
# Index(['Unnamed: 0', 'Original Title', 'Company', 'Rate', 'Metascore',
#        'Minutes', 'Release', 'Budget', 'Opening Weekend USA', 'Gross USA',
#        'Gross Worldwide', 'Profit'],
#       dtype='object')

# %%
df_5 = df.sort_values('Profit', ascending=False)
sns.barplot(x = df_5['Original Title'], y = df_5['Profit'], data=df_5, order = df_5['Original Title'][:10] , palette = 'Reds_d')
plt.xticks(rotation = 90)
plt.title('Profit Created')
plt.xlabel('Movie Title')
plt.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')
